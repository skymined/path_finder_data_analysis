# %%
import pandas as pd

# %%
df = pd.read_csv('../data/data_visitor_region_2020_2023.csv',encoding='euc-kr')
df
# Out:
#       광역지자체명 기초지자체명   광역지자체 방문자 수  광역지자체 방문자 비율  기초지자체 방문자 수  기초지자체 방문자 비율
# 0    강원특별자치도    춘천시  1.935861e+09           4.2  423446570.0          16.5
# 1    강원특별자치도    원주시  1.935861e+09           4.2  451614095.0          17.6
# 2    강원특별자치도    강릉시  1.935861e+09           4.2  379654335.0          14.8
# 3    강원특별자치도    동해시  1.935861e+09           4.2  136981278.0           5.3
# 4    강원특별자치도    태백시  1.935861e+09           4.2   69885568.0           2.7
# ..       ...    ...           ...           ...          ...           ...
# 245     충청북도    증평군  1.539516e+09           3.3   58808887.0           2.7
# 246     충청북도    진천군  1.539516e+09           3.3  111822113.0           5.2
# 247     충청북도    괴산군  1.539516e+09           3.3   63870339.0           3.0
# 248     충청북도    음성군  1.539516e+09           3.3  154752987.0           7.2
# 249     충청북도    단양군  1.539516e+09           3.3   56401444.0           2.6
#
# [250 rows x 6 columns]
